# %% [markdown]
# # This scripts runs phase plane analysis and nullclines for predator-prey framework

# %% [markdown]
# ### Part A) Phanse plane analysis and nullclines under different interaction strength with no fishing
#
# ### Part B) Phase plane analysis and nullclines under different interaction strength with predator fishing

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import rc
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.optimize import curve_fit
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
from scipy import optimize
from scipy.optimize import fsolve

# %% [markdown]
# ## Functions to Run the Model

# %%
# Define the predator-prey model based on your equations
def dNdt(state, t, parameters_dict):
    H, P = state  # Unpack state as H and P
    r_H = parameters_dict['r_H']
    K_H = parameters_dict['K_H']
    theta_H = parameters_dict['theta_H']
    c = parameters_dict['c']
    d = parameters_dict['d']
    q_H = parameters_dict['q_H']
    E_H = parameters_dict['E_H']
    r_P = parameters_dict['r_P']
    K_P = parameters_dict['K_P']
    b = parameters_dict['b']
    theta_P = parameters_dict['theta_P']
    q_P = parameters_dict['q_P']
    E_P = parameters_dict['E_P']
    
    # Equations for rate of change
    dH = r_H * H * (1 - H / K_H) - (c * H * P) / (d + H) + theta_H - q_H * E_H * H
    dP = r_P * P * (1 - P / K_P) + (b * H * P) / (d + H) + theta_P - q_P * E_P * P
    return [dH, dP]

# %%
def RK2(state, parameters_dict, t=0):
    H, P = state

    # Initial derivatives
    dH1, dP1 = dNdt(state, t, parameters_dict)

    # Intermediate step
    H1 = H + 0.5 * dH1
    P1 = P + 0.5 * dP1
    intermediate_state = [H1, P1]
    
    # Second derivatives at intermediate step
    dH2, dP2 = dNdt(intermediate_state, t, parameters_dict)

    # Average derivatives
    dH_ave = (dH1 + dH2) / 2
    dP_ave = (dP1 + dP2) / 2

    # Update state
    H = H + dH_ave
    P = P + dP_ave

    # Calculate harvest
    q_H = parameters_dict['q_H']  # Proportionality constant for herbivore harvest
    E_H = parameters_dict['E_H']  # Effort for herbivore harvest
    q_P = parameters_dict['q_P']  # Proportionality constant for predator harvest
    E_P = parameters_dict['E_P']  # Effort for predator harvest

    herbivore_harvest = q_H * E_H * H
    predator_harvest = q_P * E_P * P

    return [H, P], herbivore_harvest, predator_harvest

# %%
def run_model(INIT_H, INIT_P, parameters_dict):
    numyears = parameters_dict['numyears']
    H_array = np.zeros(numyears + 1)
    P_array = np.zeros(numyears + 1)
    H_harvest_array = np.zeros(numyears + 1)
    P_harvest_array = np.zeros(numyears + 1)

    H_array[0] = INIT_H  # Starting biomass of herbivore
    P_array[0] = INIT_P  # Starting biomass of predator
    state = [INIT_H, INIT_P]

    # Simulation loop
    for i in np.arange(0, numyears):
        state, herbivore_harvest, predator_harvest = RK2(state, parameters_dict)
        H_array[i + 1], P_array[i + 1] = state
        H_harvest_array[i + 1] = herbivore_harvest
        P_harvest_array[i + 1] = predator_harvest

    return H_array, P_array, H_harvest_array, P_harvest_array

# %% [markdown]
# ## Defining Default Parameters

# %%
def default_params():
    numyears = 300
    #Herbivore parameters:
    r_H = 0.4 # growth rate of herbivores
    K_H = 5000 # carrying capacity of herbivores
    theta_H = 50 # immigration of herbivores
    c = 0.1 #additional mortality of H 
    d = 500 # value of H when predation half its max value 
    q_H = 1. # proportionality constant for herbivore harvest 
    E_H = 0.0 # Effort for herbivore harvest (0.05 = limit cycle, 0.2 = stable state)
    #Predator parameters:
    r_P = 0.2 # growth rate of predator 
    K_P = 2000 # carrying capactiy of predators
    b = 0.1 # additional growth of P due to H
    theta_P = 10 # immigration of predators 
    q_P = 1. # proportionality constant for predator harvest 
    E_P = 0.0 # Effort for predator harvest

    parameters_dict = {'numyears': numyears, 
                  'r_H': r_H, 
                  'K_H': K_H, 
                  'theta_H': theta_H,
                  'c': c, 
                  'd': d, 
                  'E_H': E_H,
                  'q_H': q_H, 
                  'r_P': r_P,
                  'K_P': K_P,
                  'theta_P': theta_P, 
                  'b': b,
                  'q_P': q_P, 
                  'E_P': E_P,
                  }

    return parameters_dict

# %%
def default_fishing_params():
    numyears = 300
    #Herbivore parameters:
    r_H = 0.4 # growth rate of herbivores
    K_H = 5000 # carrying capacity of herbivores
    theta_H = 50 # immigration of herbivores
    c = 0.1 #additional mortality of H 
    d = 500 # value of H when predation half its max value 
    q_H = 1. # proportionality constant for herbivore harvest 
    E_H = 0.0 # Effort for herbivore harvest (0.05 = limit cycle, 0.2 = stable state)
    #Predator parameters:
    r_P = 0.2 # growth rate of predator 
    K_P = 2000 # carrying capactiy of predators
    b = 0.1 # additional growth of P due to H
    theta_P = 10 # immigration of predators 
    q_P = 1. # proportionality constant for predator harvest 
    E_P = 0.4 # Effort for predator harvest

    parameters_dict = {'numyears': numyears, 
                  'r_H': r_H, 
                  'K_H': K_H, 
                  'theta_H': theta_H,
                  'c': c, 
                  'd': d, 
                  'E_H': E_H,
                  'q_H': q_H, 
                  'r_P': r_P,
                  'K_P': K_P,
                  'theta_P': theta_P, 
                  'b': b,
                  'q_P': q_P, 
                  'E_P': E_P,
                  }

    return parameters_dict

# %% [markdown]
# ### Set Up

# %%
# Define interaction strengths and initial conditions
numyears = 300
H0 = 100
P0 = 10
b_values = [0.1, 0.4, 0.6]
c_values = [0.1, 0.4, 0.6]

# Subplot labels
subplot_labels = ["A", "B", "C", "D", "E", "F"]

# To store results
results = {}

# %% [markdown]
# ## Running through each combination of b / c values for trajectories

# %%
parameters_dict = default_params()

# Run model for each combination of b and c and store in results
for i, b in enumerate(b_values):
    for j, c in enumerate(c_values):
        parameters_dict['b'] = b
        parameters_dict['c'] = c
        H_array, P_array, H_harvest_array, P_harvest_array = run_model(H0, P0, parameters_dict)
        T_array = H_array + P_array  # Total abundance
        
        results[(i, j)] = {
            'H_array': H_array,
            'P_array': P_array,
            'T_array': T_array
        }

# %% [markdown]
# ## Function for plotting nullclines and vector field

# %%
# Define a function to plot both the nullclines and vector field

def plot_nullclines_and_vector_field(ax, rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep, is_first_subplot):
    # Create grid for phase plane analysis
    H = np.linspace(-200, 8000, 20)  # Herbivore population
    P = np.linspace(-200, 8000, 20)  # Predator population
    H_grid, P_grid = np.meshgrid(H, P)
    
    # Set parameters (immigration for both populations = 0)
    parameters_dict = {
        'r_H': rh, 'K_H': kh, 'theta_H': 0, 'c': c, 'd': d, 'q_H': qh, 'E_H': Eh,
        'r_P': rp, 'K_P': kp, 'b': b, 'theta_P': 0, 'q_P': qp, 'E_P': Ep
    }

    # Compute vector field
    dH_grid, dP_grid = np.zeros(H_grid.shape), np.zeros(P_grid.shape)
    for i in range(H_grid.shape[0]):
        for j in range(H_grid.shape[1]):
            dH_grid[i, j], dP_grid[i, j] = dNdt([H_grid[i, j], P_grid[i, j]], 0, parameters_dict)

    # Normalize vectors for plotting
    magnitude = np.sqrt(dH_grid**2 + dP_grid**2)
    dH_grid /= magnitude
    dP_grid /= magnitude

    # Create a grid of points for nullclines
    x_vals = np.linspace(-200, 8000, 100)
    y_vals = np.linspace(-200, 8000, 100)
    X, Y = np.meshgrid(x_vals, y_vals)

    # Nullcline for Prey (H)
    dHdt = (rh * X * ((kh - X) / kh)) - ((c * X * Y) / (d + X)) - (qh * Eh * X)
    # Nullcline for Predator (P)
    dPdt = (rp * Y * ((kp - Y) / kp)) + ((b * X * Y) / (d + X)) - (qp * Ep * Y)

    # Plot the vector field (gray arrows)
    ax.quiver(H_grid, P_grid, dH_grid, dP_grid, color="gray", alpha=0.6, angles="xy")
    
    # Prey Nullcline: where dHdt = 0
    prey_nullcline = ax.contour(X, Y, dHdt, levels=[0], colors="green")
    
    # Predator Nullcline: where dPdt = 0
    predator_nullcline = ax.contour(X, Y, dPdt, levels=[0], colors="purple")

    # Labels and title
    ax.set_xlabel("Prey Abundance", fontsize = 16)
    ax.set_ylabel("Predator Abundance", fontsize = 16)
    ax.set_title(f"$b$ = {b}, $c$ = {c}", fontsize = 18)
    
    # Legend for nullclines only in the first subplot
    if is_first_subplot:
        ax.legend([prey_nullcline.collections[0], predator_nullcline.collections[0]],
                  ["Prey Nullcline", "Predator Nullcline"],
                  loc="upper right", fontsize = 14)

# %% [markdown]
# ## Plot

# %%
# Define different b, c combinations
b_c_values = [(0.1, 0.1), (0.4, 0.4), (0.6, 0.6)]
fig, axs = plt.subplots(2, 3, figsize=(18, 12))

# Coordinates for closed red circles (stable equilibrium) 
closed_circle_positions = [
    (4236.07, 2894.43), 
    (0, 2000), 
    (0, 2000)
]  

# Coordinates for open red circles (unstable equilibrium)
open_circle_positions = [
    [(0, 0), (5000, 0)],
    [(0, 0), (5000, 0)],
    [(0, 0), (5000, 0)],
]

# Loop through the subplots and plot for each b, c combination
for i, (b, c) in enumerate(b_c_values):
    
    # Plot trajectories in the top row
    H_array = results[(i, i)]['H_array']
    P_array = results[(i, i)]['P_array']
    # T_array = results[(i, i)]['T_array'] # Can add in total abundance if wanted
    
    axs[0, i].plot(range(numyears + 1), H_array, label='Prey', color="green") # plotting prey trajectories 
    axs[0, i].plot(range(numyears + 1), P_array, label='Predator', color="purple") # plotting predator trajectories
    axs[0, i].set_title(f'$b$ = {b}, $c$ = {c}', fontsize=18)
    axs[0, i].set_ylim(0, 5500)
    axs[0, i].set_xlabel('Time in Years', fontsize=16)
    axs[0, i].set_ylabel('Abundance', fontsize=16)

    # Add legend only for the first trajectory subplot
    if i == 0:
        axs[0, i].legend(fontsize=14,  loc='lower right')
    
    # Add subplot label in the top-left corner
    axs[0, i].text(-0.1, 1.1, subplot_labels[i], transform=axs[0, i].transAxes,
                   fontsize=16, fontweight="bold", va="top", ha="right")

    # Plot nullclines in the bottom row
    plot_nullclines_and_vector_field(axs[1, i], 0.4, 5000, c, 500, 0.2, 2000, b, 1.0, 0.0, 1.0, 0.0, is_first_subplot=(i==0))

    # Add subplot label in the top-right corner
    axs[1, i].text(-0.1, 1.1, subplot_labels[i + 3], transform=axs[1, i].transAxes,
                   fontsize=16, fontweight="bold", va="top", ha="right")

    # Add closed red circles to nullclines (stable equilibria points)
    x_closed, y_closed = closed_circle_positions[i] 
    axs[1, i].plot(x_closed, y_closed, 'o', color='red', markersize=12, alpha=0.8)
    
    # Add open red circles to nullclines (unstable equilibria points)
    for x_open, y_open in open_circle_positions[i]:  
        axs[1, i].plot(
            x_open, y_open, 'o', 
            color='red', markerfacecolor='none', 
            markeredgewidth=2, markersize=10, 
            alpha=0.9,
        )

# Adjusting spacing
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Option to save fig
# plt.savefig("manuscript_figs/phase_plane_no_fishing.jpg",
#            format='jpeg',
#            dpi=300,
#            bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Calculate the intersection

# %%
# Function to calculate nullcline intersections
def find_all_nullcline_intersections(rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep, H_range, P_range, grid_resolution=50):
    def system(vars):
        H, P = vars
        # Nullcline equations
        dHdt = (rh * H * ((kh - H) / kh)) - ((c * H * P) / (d + H)) - (qh * Eh * H)
        dPdt = (rp * P * ((kp - P) / kp)) + ((b * H * P) / (d + H)) - (qp * Ep * P)
        return [dHdt, dPdt]
    
    # Generate grid points
    H_values = np.linspace(H_range[0], H_range[1], grid_resolution)
    P_values = np.linspace(P_range[0], P_range[1], grid_resolution)
    intersections = []
    
    for H_guess in H_values:
        for P_guess in P_values:
            # Solve using initial guess
            solution, info, ier, _ = fsolve(system, [H_guess, P_guess], full_output=True)
            
            # Check if the solver converged
            if ier == 1:
                # Round solution to avoid duplicates
                H_sol, P_sol = np.round(solution, decimals=5)
                # Ensure solution is within valid ranges and not already recorded
                if H_range[0] <= H_sol <= H_range[1] and P_range[0] <= P_sol <= P_range[1]:
                    # Check for duplicates 
                    if len(intersections) == 0 or not any(np.isclose(np.array(intersections), (H_sol, P_sol), atol=0.1).all(axis=1)):
                        intersections.append((H_sol, P_sol))
    
    return intersections

# Define parameters for each subplot
parameters_list = [
    (0.4, 5000, 0.1, 500, 0.2, 2000, 0.1, 1.0, 0.0, 1.0, 0.0),  # For subplot 1
    (0.4, 5000, 0.4, 500, 0.2, 2000, 0.4, 1.0, 0.0, 1.0, 0.0),  # For subplot 2
    (0.4, 5000, 0.6, 500, 0.2, 2000, 0.6, 1.0, 0.0, 1.0, 0.0),  # For subplot 3
]

# Define search ranges for H and P
H_range = (0, 8000) 
P_range = (0, 8000) 

# Find and print all intersection points for each subplot
for idx, params in enumerate(parameters_list):
    rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep = params
    intersections = find_all_nullcline_intersections(rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep, H_range, P_range)
    print(f"Subplot {idx + 1}: Found {len(intersections)} intersection points:")
    for H, P in intersections:
        print(f"  Prey (H) = {H:.2f}, Predator (P) = {P:.2f}")
# Out:
# Subplot 1: Found 4 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = -0.00, Predator (P) = 2000.00
#   Prey (H) = 4236.07, Predator (P) = 2894.43
#   Prey (H) = 5000.00, Predator (P) = 0.00
# Subplot 2: Found 3 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = 0.00, Predator (P) = 2000.00
#   Prey (H) = 5000.00, Predator (P) = -0.00
# Subplot 3: Found 3 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = -0.00, Predator (P) = 2000.00
#   Prey (H) = 5000.00, Predator (P) = 0.00

# %% [markdown]
# ## Add Predator Fishing

# %%
numyears = 300
H0 = 100
P0 = 10
parameters_dict = default_fishing_params()

# Run model for each combination of b and c and store in results
for i, b in enumerate(b_values):
    for j, c in enumerate(c_values):
        parameters_dict['b'] = b
        parameters_dict['c'] = c
        H_array, P_array, H_harvest_array, P_harvest_array = run_model(H0, P0, parameters_dict)
        T_array = H_array + P_array  # Total abundance
        
        results[(i, j)] = {
            'H_array': H_array,
            'P_array': P_array,
            'T_array': T_array
        }

# %%
# Create subplots for different b, c combinations
b_c_values = [(0.1, 0.1), (0.4, 0.4), (0.6, 0.6)]
fig, axs = plt.subplots(2, 3, figsize=(18, 12))

# Coordinates for closed red circles (stable equilibrium) 
closed_circle_positions = [
    (5000, 0), 
    (2937, 1418), 
    (365, 534)
]  

# Coordinates for open red circles (unstable equilibrium)
open_circle_positions = [
    [(0, 0)],
    [(0, 0), (5000, 0)],
    [(0, 0), (5000, 0)],
]

# Loop through the subplots and plot for each b, c combination
for i, (b, c) in enumerate(b_c_values):
    # Plot trajectories in the top row
    H_array = results[(i, i)]['H_array']
    P_array = results[(i, i)]['P_array']
    #T_array = results[(i, i)]['T_array']
    
    axs[0, i].plot(range(numyears + 1), H_array, label='Prey', color="green")
    axs[0, i].plot(range(numyears + 1), P_array, label='Predator', color="purple")
    axs[0, i].set_title(f'$b$ = {b}, $c$ = {c}', fontsize=18)
    axs[0, i].set_xlabel('Time in Years', fontsize=16)
    axs[0, i].set_ylabel('Abundance', fontsize=16)
    axs[0, i].set_ylim(0, 5500) 

    # Add legend only for the first trajectory subplot
    if i == 0:
        axs[0, i].legend(fontsize=14, loc='center right')
    
    # Add subplot label in the top-left corner
    axs[0, i].text(-0.1, 1.1, subplot_labels[i], transform=axs[0, i].transAxes,
                   fontsize=16, fontweight="bold", va="center", ha="right")

    # Plot nullclines in the bottom row
    plot_nullclines_and_vector_field(axs[1, i], 0.4, 5000, c, 500, 0.2, 2000, b, 1.0, 0.0, 1.0, 0.4, is_first_subplot=(i==0))

    # Add subplot label in the top-left corner
    axs[1, i].text(-0.1, 1.1, subplot_labels[i + 3], transform=axs[1, i].transAxes,
                   fontsize=16, fontweight="bold", va="top", ha="right")

    # Add closed red circles to nullclines (stable equilibria points)
    x_closed, y_closed = closed_circle_positions[i] 
    axs[1, i].plot(x_closed, y_closed, 'o', color='red', markersize=12, alpha=0.8)
    
    # Add open red circles to nullclines (unstable equilibria points)
    for x_open, y_open in open_circle_positions[i]:  
        axs[1, i].plot(
            x_open, y_open, 'o', 
            color='red', markerfacecolor='none', 
            markeredgewidth=2, markersize=10, 
            alpha=0.9
        )
    
# Adjusting spacing
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Option to save fig
# plt.savefig("manuscript_figs/phase_plane_pred_fishing.jpg",
#            format='jpeg',
#            dpi=300,
#            bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Solving for abundance values of nullcline intersections

# %%
# Function to calculate nullcline intersections
def find_all_nullcline_intersections(rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep, H_range, P_range, grid_resolution=50):
    def system(vars):
        H, P = vars
        # Nullcline equations
        dHdt = (rh * H * ((kh - H) / kh)) - ((c * H * P) / (d + H)) - (qh * Eh * H)
        dPdt = (rp * P * ((kp - P) / kp)) + ((b * H * P) / (d + H)) - (qp * Ep * P)
        return [dHdt, dPdt]
    
    # Generate grid points
    H_values = np.linspace(H_range[0], H_range[1], grid_resolution)
    P_values = np.linspace(P_range[0], P_range[1], grid_resolution)
    intersections = []
    
    for H_guess in H_values:
        for P_guess in P_values:
            # Solve using initial guess
            solution, info, ier, _ = fsolve(system, [H_guess, P_guess], full_output=True)
            
            # Check if the solver converged
            if ier == 1:
                # Round solution to avoid duplicates
                H_sol, P_sol = np.round(solution, decimals=5)
                # Ensure solution is within valid ranges and not already recorded
                if H_range[0] <= H_sol <= H_range[1] and P_range[0] <= P_sol <= P_range[1]:
                    # Check for duplicates but do not print
                    if len(intersections) == 0 or not any(np.isclose(np.array(intersections), (H_sol, P_sol), atol=0.1).all(axis=1)):
                        intersections.append((H_sol, P_sol))
    
    return intersections

# Define parameters for each subplot
parameters_list = [
    (0.4, 5000, 0.1, 500, 0.2, 2000, 0.1, 1.0, 0.0, 1.0, 0.4),  # For subplot 1
    (0.4, 5000, 0.4, 500, 0.2, 2000, 0.4, 1.0, 0.0, 1.0, 0.4),  # For subplot 2
    (0.4, 5000, 0.6, 500, 0.2, 2000, 0.6, 1.0, 0.0, 1.0, 0.4),  # For subplot 3
]

# Define search ranges for H and P
H_range = (0, 8000)  # Adjust range based on expected prey abundance
P_range = (0, 8000)  # Adjust range based on expected predator abundance

# Find and print all intersection points for each subplot
for idx, params in enumerate(parameters_list):
    rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep = params
    intersections = find_all_nullcline_intersections(rh, kh, c, d, rp, kp, b, qh, Eh, qp, Ep, H_range, P_range)
    print(f"Subplot {idx + 1}: Found {len(intersections)} intersection points:")
    for H, P in intersections:
        print(f"  Prey (H) = {H:.2f}, Predator (P) = {P:.2f}")
# Out:
# Subplot 1: Found 2 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = 5000.00, Predator (P) = -0.00
# Subplot 2: Found 3 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = 2937.02, Predator (P) = 1418.10
#   Prey (H) = 5000.00, Predator (P) = 0.00
# Subplot 3: Found 3 intersection points:
#   Prey (H) = 0.00, Predator (P) = 0.00
#   Prey (H) = 365.79, Predator (P) = 534.97
#   Prey (H) = 5000.00, Predator (P) = 0.00
