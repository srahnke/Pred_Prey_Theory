# %% [markdown]
# # This script performs the analysis in the supplemental Figure S7:
#
# ### $b$, $c$, and $E_P$ ampltiude, plus pred-prey trajectories

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import rc
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.optimize import curve_fit
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
from matplotlib.patches import Patch
from scipy.signal import find_peaks

# %% [markdown]
# ## Pred - Prey Model Functions

# %%
def dNdt(H, P, parameters_dict):
    #Unpacking herbivore parameters:
    r_H = parameters_dict['r_H'] # growth rate of herbivores
    K_H = parameters_dict['K_H'] # carrying capacity of herbivores
    theta_H = parameters_dict['theta_H'] # immigration of herbivores
    c = parameters_dict['c'] # addition to predator from prey
    d = parameters_dict['d'] # value of H when predation half its max value
    q_H = parameters_dict['q_H'] # proportionality constant for herbivore harvest
    E_H = parameters_dict['E_H'] # Effort for herbivore harvest
    #Unpacking predator parameters:
    r_P = parameters_dict['r_P'] # growth rate of predator 
    K_P = parameters_dict['K_P'] # carrying capactiy of predators 
    b = parameters_dict['b'] # mortality to prey from predator
    theta_P = parameters_dict['theta_P'] # immigration of predators  
    q_P = parameters_dict['q_P'] # proportionality constant for predators harvest
    E_P = parameters_dict['E_P'] # Effort for predator harvest
    
    #Calculate the derivative 
    dH = r_H*H*(1-H/K_H) - (c*H*P)/(d+H) + theta_H - q_H*E_H*H
    dP = r_P*P*(1-P/K_P) + (b*H*P)/(d+H) + theta_P - q_P*E_P*P
    
    return dH, dP

# %%
# Function: numerical solver, 2nd order RK 

def RK2(H, P, parameters_dict):
    H_init = H
    P_init = P 
    
    dH1, dP1 = dNdt(H,P,parameters_dict)
    
    H1 = H + 0.5*dH1
    P1 = P + 0.5*dP1
    
    dH2, dP2 = dNdt(H1,P1,parameters_dict)
    
    dH_ave = (dH1+dH2)/2 
    dP_ave = (dP1+dP2)/2 
    
    H = H_init + dH_ave
    P = P_init + dP_ave
    
    #Calculate harvest 
    q_H = parameters_dict['q_H'] #proportionality constant for herbivore harvest 
    E_H = parameters_dict['E_H'] #Effort for herbivore harvest
    
    q_P = parameters_dict['q_P'] #proportionality constant for herbivore harvest 
    E_P = parameters_dict['E_P'] #Effort for herbivore harvest
    
    herbivore_harvest = q_H*E_H*H
    predator_harvest = q_P*E_P*P
    
    return H, P, herbivore_harvest, predator_harvest

# %%
# Function to run the model 

def run_model(INIT_H, INIT_P, parameters_dict):
    
    numyears = parameters_dict['numyears']
    
    H_array = np.zeros(numyears+1)
    P_array = np.zeros(numyears+1)
    H_harvest_array = np.zeros(numyears+1)
    P_harvest_array = np.zeros(numyears+1)
    
    H_array[0] = INIT_H #Starting biomass of herbivore 
    P_array[0] = INIT_P #Starting biomass of predator 
    H_harvest_array[0] = 0
    P_harvest_array[0] = 0
    
    for i in np.arange(0,numyears):
        H_array[i+1], P_array[i+1], H_harvest_array[i+1], P_harvest_array[i+1] \
            = RK2(H_array[i], P_array[i], parameters_dict)
        i = i+1
    
    return H_array, P_array, H_harvest_array, P_harvest_array

# %% [markdown]
# ## Define a function to set to normal params

# %%
def default_params():
    numyears = 1000
    #Herbivore parameters:
    r_H = 0.4 # growth rate of herbivores
    K_H = 5000 # carrying capacity of herbivores
    theta_H = 50 # immigration of herbivores
    c = 0.4 #additional mortality of H 
    d = 500 # value of H when predation half its max value 
    q_H = 1. # proportionality constant for herbivore harvest 
    E_H = 0.0 # Effort for herbivore harvest (0.05 = limit cycle, 0.2 = stable state)
    #Predator parameters:
    r_P = 0.2 # growth rate of predator 
    K_P = 2000 # carrying capactiy of predators
    b = 0.4 # additional growth of P due to H
    theta_P = 10 # immigration of predators 
    q_P = 1. # proportionality constant for predator harvest 
    E_P = 0.0 # Effort for predator harvest

    parameters_dict = {'numyears': numyears, 
                  'r_H': r_H, 
                  'K_H': K_H, 
                  'theta_H': theta_H,
                  'c': c, 
                  'd': d, 
                  'E_H': E_H,
                  'q_H': q_H, 
                  'r_P': r_P,
                  'K_P': K_P,
                  'theta_P': theta_P, 
                  'b': b,
                  'q_P': q_P, 
                  'E_P': E_P,
                  }

    return parameters_dict

# %%
#Run model simulation; set params to default
parameters_dict = default_params()

H0 = 100
P0 = 10

H_array, P_array, H_harvest_array, P_harvest_array = run_model(H0, P0, parameters_dict)

# %% [markdown]
# ## Supplemental Fig 5 - b, c, & EP values

# %% [markdown]
# ### With Cycle hatches

# %%
def detect_cycles(ts, min_peaks=2, min_amplitude=10, tail_length=100):
    ts = np.asarray(ts)[-tail_length:]
    if (np.max(ts) - np.min(ts)) < min_amplitude:
        return False

    ts_centered = ts - np.mean(ts)
    peaks, _ = find_peaks(ts_centered, height=min_amplitude / 2)
    troughs, _ = find_peaks(-ts_centered, height=min_amplitude / 2)

    return (len(peaks) >= min_peaks) and (len(troughs) >= min_peaks)

size = 500
tail_length = 100

parameters_dict = default_params()
b_array = np.linspace(0, 1.0, size)
c_array = np.linspace(0, 1.0, size)
E_P_array = np.linspace(0, 2.0, size)

predator_extinction = 10
prey_extinction = 50

region_data_b = np.zeros((size, size))
region_data_c = np.zeros((size, size))

H_last_b, P_last_b = np.zeros((size, size)), np.zeros((size, size))

mask_cycles_H_b = np.zeros((size, size), dtype=bool)
mask_cycles_P_b = np.zeros((size, size), dtype=bool)

for i in range(size):
    for j in range(size):
        b = b_array[i]
        E_P = E_P_array[j]
        parameters_dict['b'] = b
        parameters_dict['E_P'] = E_P
        
        # Reset c to a default
        parameters_dict['c'] = 0.4
        
        H_array, P_array, _, _ = run_model(H0, P0, parameters_dict)

        H_tail = H_array[-tail_length:]
        P_tail = P_array[-tail_length:]
        H_last_b[i, j] = np.mean(H_tail)
        P_last_b[i, j] = np.mean(P_tail)

        mask_cycles_H_b[i, j] = detect_cycles(H_tail)
        mask_cycles_P_b[i, j] = detect_cycles(P_tail)

mask_P_dominated_b = (H_last_b < prey_extinction) & (P_last_b > predator_extinction)
mask_H_dominated_b = (P_last_b < predator_extinction) & (H_last_b > prey_extinction)
mask_extinction_b = (H_last_b < prey_extinction) & (P_last_b < predator_extinction)
mask_coexistence_b = (H_last_b > prey_extinction) & (P_last_b > predator_extinction)

region_data_b[mask_extinction_b] = 1
region_data_b[mask_P_dominated_b] = 2
region_data_b[mask_H_dominated_b] = 3
region_data_b[mask_coexistence_b] = 4

constrained_mask_cycles_H_b = mask_cycles_H_b & mask_coexistence_b
constrained_mask_cycles_P_b = mask_cycles_P_b & mask_coexistence_b

H_last_c, P_last_c = np.zeros((size, size)), np.zeros((size, size))

mask_cycles_H_c = np.zeros((size, size), dtype=bool)
mask_cycles_P_c = np.zeros((size, size), dtype=bool)

for i in range(size):
    for j in range(size):
        c = c_array[i]
        E_P = E_P_array[j]
        parameters_dict['c'] = c
        parameters_dict['E_P'] = E_P
        
        # Reset b to a default
        parameters_dict['b'] = 0.4 
        
        H_array, P_array, _, _ = run_model(H0, P0, parameters_dict)

        H_tail = H_array[-tail_length:]
        P_tail = P_array[-tail_length:]
        H_last_c[i, j] = np.mean(H_tail)
        P_last_c[i, j] = np.mean(P_tail)

        mask_cycles_H_c[i, j] = detect_cycles(H_tail)
        mask_cycles_P_c[i, j] = detect_cycles(P_tail)

mask_P_dominated_c = (H_last_c < prey_extinction) & (P_last_c > predator_extinction)
mask_H_dominated_c = (P_last_c < predator_extinction) & (H_last_c > prey_extinction)
mask_extinction_c = (H_last_c < prey_extinction) & (P_last_c < predator_extinction)
mask_coexistence_c = (H_last_c > prey_extinction) & (P_last_c > predator_extinction)

region_data_c[mask_extinction_c] = 1
region_data_c[mask_P_dominated_c] = 2
region_data_c[mask_H_dominated_c] = 3
region_data_c[mask_coexistence_c] = 4

constrained_mask_cycles_H_c = mask_cycles_H_c & mask_coexistence_c
constrained_mask_cycles_P_c = mask_cycles_P_c & mask_coexistence_c

# %% [markdown]
# ### Save Output

# %%
# Save b sweep data
np.save("data/region_data_b_1050.npy", region_data_b)
np.save("data/H_last_b_1050.npy", H_last_b)
np.save("data/P_last_b_1050.npy", P_last_b)
np.save("data/mask_cycles_H_b_1050.npy", mask_cycles_H_b)
np.save("data/mask_cycles_P_b_1050.npy", mask_cycles_P_b)
np.save("data/constrained_mask_cycles_H_b_1050.npy", constrained_mask_cycles_H_b)
np.save("data/constrained_mask_cycles_P_b_1050.npy", constrained_mask_cycles_P_b)

# Save c sweep data
np.save("data/region_data_c_1050.npy", region_data_c)
np.save("data/H_last_c_1050.npy", H_last_c)
np.save("data/P_last_c_1050.npy", P_last_c)
np.save("data/mask_cycles_H_c_1050.npy", mask_cycles_H_c)
np.save("data/mask_cycles_P_c_1050.npy", mask_cycles_P_c)
np.save("data/constrained_mask_cycles_H_c_1050.npy", constrained_mask_cycles_H_c)
np.save("data/constrained_mask_cycles_P_c_1050.npy", constrained_mask_cycles_P_c)

# %% [markdown]
# ## Load for plotting

# %%
region_data_b = np.load("data/region_data_b_1050.npy")
H_last_b = np.load("data/H_last_b_1050.npy")
P_last_b = np.load("data/P_last_b_1050.npy")
mask_cycles_H_b = np.load("data/mask_cycles_H_b_1050.npy")
mask_cycles_P_b = np.load("data/mask_cycles_P_b_1050.npy")
constrained_mask_cycles_H_b = np.load("data/constrained_mask_cycles_H_b_1050.npy")
constrained_mask_cycles_P_b = np.load("data/constrained_mask_cycles_P_b_1050.npy")

region_data_c = np.load("data/region_data_c_1050.npy")
H_last_c = np.load("data/H_last_c_1050.npy")
P_last_c = np.load("data/P_last_c_1050.npy")
mask_cycles_H_c = np.load("data/mask_cycles_H_c_1050.npy")
mask_cycles_P_c = np.load("data/mask_cycles_P_c_1050.npy")
constrained_mask_cycles_H_c = np.load("data/constrained_mask_cycles_H_c_1050.npy")
constrained_mask_cycles_P_c = np.load("data/constrained_mask_cycles_P_c_1050.npy")


size = 500
tail_length = 100

parameters_dict = default_params()
b_array = np.linspace(0, 1.0, size)
c_array = np.linspace(0, 1.0, size)
E_P_array = np.linspace(0, 2.0, size)

# %%
# Create meshgrids for contour alignment
EP_grid, b_grid = np.meshgrid(E_P_array, b_array)
EP_grid_c, c_grid = np.meshgrid(E_P_array, c_array)

# Define colormap for regions
cmap = ListedColormap(['purple', 'gray', 'green', 'lightblue'])

# --- Plotting ---
fig, axs = plt.subplots(1, 2, figsize=(18, 7))

# --- Panel A: b vs E_P ---
im_b = axs[0].imshow(region_data_b, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

# Overlay hatches for cycles
axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_H_b.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)

axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_P_b.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

# Labels and formatting
axs[0].text(0.0, 1.01, 'A', color='black', fontsize=18, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.03, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.3, 0.55, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.75, 0.4, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
axs[0].set_xlabel("$E_P$ values", fontsize=18)
axs[0].set_ylabel("$b$ values", fontsize=18)
axs[0].tick_params(axis='both', labelsize=16)

# --- Panel B: c vs E_P ---
im_c = axs[1].imshow(region_data_c, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), c_array.min(), c_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

# Overlay hatches for cycles
axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_H_c.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)

axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_P_c.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

# Labels and formatting
axs[1].text(0.0, 1.01, 'B', color='black', fontsize=18, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.015, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.3, 0.6, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.7, 0.55, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
axs[1].set_xlabel("$E_P$ values", fontsize=18)
axs[1].set_ylabel("$c$ values", fontsize=18)
axs[1].tick_params(axis='both', labelsize=16)

# --- Legend ---
hatch_patch_H = Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles')
hatch_patch_P = Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
axs[0].legend(handles=[hatch_patch_H, hatch_patch_P], loc='upper right', fontsize=14, frameon=True)


plt.tight_layout()

#plt.savefig("manuscript_figs/b_c_EP_regions_cycles.jpg",
 #           format='jpeg',
  #          dpi=300,
   # bbox_inches='tight')

plt.show()

# %%
# Create meshgrids for contour alignment
EP_grid, b_grid = np.meshgrid(E_P_array, b_array)
EP_grid_c, c_grid = np.meshgrid(E_P_array, c_array)

# Define colormap
cmap = ListedColormap(['purple', 'gray', 'green', 'lightblue'])

# --- Plotting ---
fig, axs = plt.subplots(1, 2, figsize=(18, 7))

# --- Panel A: b vs E_P ---
im_b = axs[0].imshow(region_data_b, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_H_b.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)
axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_P_b.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

axs[0].text(0.0, 1.01, 'A', fontsize=18, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.03, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.3, 0.55, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
#axs[0].text(0.75, 0.4, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
axs[0].set_xlabel("$E_P$ values", fontsize=18)
axs[0].set_ylabel("$b$ values", fontsize=18)
axs[0].tick_params(axis='both', labelsize=16)

# --- Panel B: c vs E_P ---
im_c = axs[1].imshow(region_data_c, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), c_array.min(), c_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_H_c.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)
axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_P_c.astype(int),
                levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

axs[1].text(0.0, 1.01, 'B', fontsize=18, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.015, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.3, 0.6, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
#axs[1].text(0.7, 0.55, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
axs[1].set_xlabel("$E_P$ values", fontsize=18)
axs[1].set_ylabel("$c$ values", fontsize=18)
axs[1].tick_params(axis='both', labelsize=16)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]

fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 1, 1])  # Leave space for legend
plt.show()

# %% [markdown]
# ## Without Hatches

# %%
# Create meshgrids for contour alignment
EP_grid, b_grid = np.meshgrid(E_P_array, b_array)
EP_grid_c, c_grid = np.meshgrid(E_P_array, c_array)

# Define colormap for regions
cmap = ListedColormap(['purple', 'gray', 'green', 'lightblue'])

# --- Plotting ---
fig, axs = plt.subplots(1, 2, figsize=(18, 7))

# --- Panel A: b vs E_P ---
im_b = axs[0].imshow(region_data_b, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

# Overlay hatches for cycles
#axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_H_b.astype(int),
 #               levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)

#axs[0].contourf(EP_grid, b_grid, constrained_mask_cycles_P_b.astype(int),
 #               levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

# Labels and formatting
axs[0].text(0.0, 1.01, 'A', color='black', fontsize=18, fontweight='bold', transform=axs[0].transAxes)
axs[0].text(0.03, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
axs[0].text(0.3, 0.55, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
axs[0].text(0.75, 0.4, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[0].transAxes)
axs[0].set_xlabel("$E_P$ values", fontsize=18)
axs[0].set_ylabel("$b$ values", fontsize=18)
axs[0].tick_params(axis='both', labelsize=16)

# --- Panel B: c vs E_P ---
im_c = axs[1].imshow(region_data_c, cmap=cmap,
                     extent=[E_P_array.min(), E_P_array.max(), c_array.min(), c_array.max()],
                     origin='lower', aspect='auto', alpha=0.5)

# Overlay hatches for cycles
#axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_H_c.astype(int),
 #               levels=[0.5, 1.5], colors='none', hatches=['////'], alpha=0)

#axs[1].contourf(EP_grid_c, c_grid, constrained_mask_cycles_P_c.astype(int),
 #               levels=[0.5, 1.5], colors='none', hatches=['\\\\'], alpha=0)

# Labels and formatting
axs[1].text(0.0, 1.01, 'B', color='black', fontsize=18, fontweight='bold', transform=axs[1].transAxes)
axs[1].text(0.015, 0.7, 'Predator\nOnly', color='darkviolet', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
axs[1].text(0.3, 0.6, 'Coexistence', color='royalblue', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
axs[1].text(0.7, 0.55, 'Prey Only', color='darkgreen', fontsize=14, fontweight='bold', transform=axs[1].transAxes)
axs[1].set_xlabel("$E_P$ values", fontsize=18)
axs[1].set_ylabel("$c$ values", fontsize=18)
axs[1].tick_params(axis='both', labelsize=16)

# --- Legend ---
#hatch_patch_H = Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles')
#hatch_patch_P = Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
#axs[0].legend(handles=[hatch_patch_H, hatch_patch_P], loc='upper right', fontsize=14, frameon=True)

plt.tight_layout()
plt.show()

# %%
# --- Report bounds of cyclic regions ---

# For Panel A (b vs E_P)
b_indices, ep_indices = np.where(constrained_mask_cycles_H_b | constrained_mask_cycles_P_b)
if len(b_indices) > 0:
    b_min, b_max = b_array[b_indices].min(), b_array[b_indices].max()
    ep_min, ep_max = E_P_array[ep_indices].min(), E_P_array[ep_indices].max()
    print(f"\nPanel A - Cyclical Region:")
    print(f"  b values range:    {b_min:.3f} to {b_max:.3f}")
    print(f"  E_P values range:  {ep_min:.3f} to {ep_max:.3f}")
else:
    print("\nPanel A - No cycles detected in coexistence region.")

# For Panel B (c vs E_P)
c_indices, ep_indices_c = np.where(constrained_mask_cycles_H_c | constrained_mask_cycles_P_c)
if len(c_indices) > 0:
    c_min, c_max = c_array[c_indices].min(), c_array[c_indices].max()
    ep_min_c, ep_max_c = E_P_array[ep_indices_c].min(), E_P_array[ep_indices_c].max()
    print(f"\nPanel B - Cyclical Region:")
    print(f"  c values range:    {c_min:.3f} to {c_max:.3f}")
    print(f"  E_P values range:  {ep_min_c:.3f} to {ep_max_c:.3f}")
else:
    print("\nPanel B - No cycles detected in coexistence region.")
# Out:
# Panel A - Cyclical Region:
#   b values range:    0.329 to 1.000
#   E_P values range:  0.277 to 0.754
#
# Panel B - Cyclical Region:
#   c values range:    0.389 to 1.000
#   E_P values range:  0.305 to 0.457

# %% [markdown]
# # Adding Amplitude Contour Lines

# %%
# --- Cycle detection ---
def detect_cycles(ts, min_peaks=2, min_amplitude=10, tail_length=100):
    ts = np.asarray(ts)[-tail_length:]
    if (np.max(ts) - np.min(ts)) < min_amplitude:
        return False

    ts_centered = ts - np.mean(ts)
    peaks, _ = find_peaks(ts_centered, height=min_amplitude / 2)
    troughs, _ = find_peaks(-ts_centered, height=min_amplitude / 2)

    return (len(peaks) >= min_peaks) and (len(troughs) >= min_peaks)

# --- Setup ---
size = 500
b_array = np.linspace(0, 1.0, size)
c_array = np.linspace(0, 1.0, size)
E_P_array = np.linspace(0, 2.0, size)
parameters_dict = default_params()

predator_extinction = 10
prey_extinction = 50

region_data_b = np.zeros((size, size))
region_data_c = np.zeros((size, size))

amp_H_b = np.zeros((size, size))
amp_P_b = np.zeros((size, size))
amp_H_c = np.zeros((size, size))
amp_P_c = np.zeros((size, size))

# --- Run model for b vs E_P ---
H_last_b, P_last_b = np.zeros((size, size)), np.zeros((size, size))

for i in range(size):
    for j in range(size):
        b = b_array[i]
        E_P = E_P_array[j]
        parameters_dict['b'] = b
        parameters_dict['E_P'] = E_P
        parameters_dict['c'] = 0.4
        H_array, P_array, *_ = run_model(H0, P0, parameters_dict)

        H_tail = H_array[-100:]
        P_tail = P_array[-100:]
        H_last_b[i, j] = np.mean(H_tail)
        P_last_b[i, j] = np.mean(P_tail)
        amp_H_b[i, j] = np.ptp(H_tail)
        amp_P_b[i, j] = np.ptp(P_tail)

        if detect_cycles(H_tail) or detect_cycles(P_tail):
            region_data_b[i, j] = 5

mask_P_dominated_b = (H_last_b < prey_extinction) & (P_last_b > predator_extinction)
mask_H_dominated_b = (P_last_b < predator_extinction) & (H_last_b > prey_extinction)
mask_extinction_b = (H_last_b < prey_extinction) & (P_last_b < predator_extinction)
mask_coexistence_b = (H_last_b > prey_extinction) & (P_last_b > predator_extinction)

mask_cycles_b = region_data_b == 5
region_data_b[mask_cycles_b] = 4

region_data_b[mask_extinction_b] = 1
region_data_b[mask_P_dominated_b] = 2
region_data_b[mask_H_dominated_b] = 3
region_data_b[mask_coexistence_b] = 4

constrained_mask_cycles_b = mask_cycles_b & (region_data_b == 4)

# --- Run model for c vs E_P ---
H_last_c, P_last_c = np.zeros((size, size)), np.zeros((size, size))

for i in range(size):
    for j in range(size):
        c = c_array[i]
        E_P = E_P_array[j]
        parameters_dict['c'] = c
        parameters_dict['E_P'] = E_P
        parameters_dict['b'] = 0.4 
        H_array, P_array, *_ = run_model(H0, P0, parameters_dict)

        H_tail = H_array[-100:]
        P_tail = P_array[-100:]
        H_last_c[i, j] = np.mean(H_tail)
        P_last_c[i, j] = np.mean(P_tail)
        amp_H_c[i, j] = np.ptp(H_tail)
        amp_P_c[i, j] = np.ptp(P_tail)

        if detect_cycles(H_tail) or detect_cycles(P_tail):
            region_data_c[i, j] = 5

mask_P_dominated_c = (H_last_c < prey_extinction) & (P_last_c > predator_extinction)
mask_H_dominated_c = (P_last_c < predator_extinction) & (H_last_c > prey_extinction)
mask_extinction_c = (H_last_c < prey_extinction) & (P_last_c < predator_extinction)
mask_coexistence_c = (H_last_c > prey_extinction) & (P_last_c > predator_extinction)

mask_cycles_c = region_data_c == 5
region_data_c[mask_cycles_c] = 4

region_data_c[mask_extinction_c] = 1
region_data_c[mask_P_dominated_c] = 2
region_data_c[mask_H_dominated_c] = 3
region_data_c[mask_coexistence_c] = 4

constrained_mask_cycles_c = mask_cycles_c & (region_data_c == 4)

amp_H_b_masked = np.where(constrained_mask_cycles_b, amp_H_b, np.nan)
amp_P_b_masked = np.where(constrained_mask_cycles_b, amp_P_b, np.nan)

amp_H_c_masked = np.where(constrained_mask_cycles_c, amp_H_c, np.nan)
amp_P_c_masked = np.where(constrained_mask_cycles_c, amp_P_c, np.nan)

# %% [markdown]
# ## Save output

# %%
# Save b vs E_P data
np.save("data/amp_H_b_1050.npy", amp_H_b)
np.save("data/amp_P_b_1050.npy", amp_P_b)
np.save("data/amp_H_b_masked_1050.npy", amp_H_b_masked)
np.save("data/amp_P_b_masked_1050.npy", amp_P_b_masked)
np.save("data/constrained_mask_cycles_b_1050.npy", constrained_mask_cycles_b)

# Save c vs E_P data
np.save("data/amp_H_c_1050.npy", amp_H_c)
np.save("data/amp_P_c_1050.npy", amp_P_c)
np.save("data/amp_H_c_masked_1050.npy", amp_H_c_masked)
np.save("data/amp_P_c_masked_1050.npy", amp_P_c_masked)
np.save("data/constrained_mask_cycles_c_1050.npy", constrained_mask_cycles_c)

# %% [markdown]
# ## Load for plotting

# %%
# b vs E_P
amp_H_b = np.load("data/amp_H_b_1050.npy")
amp_P_b = np.load("data/amp_P_b_1050.npy")
amp_H_b_masked = np.load("data/amp_H_b_masked_1050.npy")
amp_P_b_masked = np.load("data/amp_P_b_masked_1050.npy")
constrained_mask_cycles_b = np.load("data/constrained_mask_cycles_b_1050.npy")

# c vs E_P
amp_H_c = np.load("data/amp_H_c_1050.npy")
amp_P_c = np.load("data/amp_P_c_1050.npy")
amp_H_c_masked = np.load("data/amp_H_c_masked_1050.npy")
amp_P_c_masked = np.load("data/amp_P_c_masked_1050.npy")
constrained_mask_cycles_c = np.load("data/constrained_mask_cycles_c_1050.npy")


size = 500
tail_length = 100

parameters_dict = default_params()
b_array = np.linspace(0, 1.0, size)
c_array = np.linspace(0, 1.0, size)
E_P_array = np.linspace(0, 2.0, size)

# %% [markdown]
# ## Plotting

# %%
amp_H_b_masked = np.where(constrained_mask_cycles_b, amp_H_b, np.nan)
amp_P_b_masked = np.where(constrained_mask_cycles_b, amp_P_b, np.nan)

amp_H_c_masked = np.where(constrained_mask_cycles_c, amp_H_c, np.nan)
amp_P_c_masked = np.where(constrained_mask_cycles_c, amp_P_c, np.nan)

# Set shared vmin/vmax for colorbars
vmin_H = np.nanmin([amp_H_b_masked, amp_H_c_masked])
vmax_H = np.nanmax([amp_H_b_masked, amp_H_c_masked])
vmin_P = np.nanmin(amp_P_b_masked)
vmax_P = np.nanmax(amp_P_b_masked)

# Prey colorbar ticks
prey_ticks = np.linspace(vmin_H, vmax_H, num=5)

# Predator colorbar ticks
pred_ticks = np.linspace(vmin_P, vmax_P, num=5)

# --- Colormaps ---
cmap_regions = ListedColormap(['purple', 'gray', 'green', 'lightblue'])

fig, axs = plt.subplots(2, 2, figsize=(18, 14))

# Panel A: Prey amplitude for b
axs[0, 0].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS0 = axs[0, 0].contourf(E_P_array, b_array, amp_H_b_masked, 
                         levels=10, cmap='viridis', alpha=0.9, 
                         vmin=vmin_H, vmax=vmax_H)

axs[0, 0].set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[0, 0].set_xlabel("$E_P$", fontsize=16)
axs[0, 0].set_ylabel("$b$", fontsize=16)
axs[0, 0].tick_params(axis='both', labelsize=14)
axs[0, 0].text(0.05, 0.7, 'Predator\nOnly', transform=axs[0, 0].transAxes, fontsize=12, color='darkviolet')
axs[0, 0].text(0.35, 0.55, 'Coexistence', transform=axs[0, 0].transAxes, fontsize=12, color='royalblue')
axs[0, 0].text(0.75, 0.4, 'Prey Only', transform=axs[0, 0].transAxes, fontsize=12, color='darkgreen')

# Panel B: Prey amplitude for c
axs[0, 1].imshow(region_data_c, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(c_array), max(c_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS1 = axs[0, 1].contourf(E_P_array, c_array, amp_H_c_masked, 
                         levels=10, cmap='viridis', alpha=0.9, 
                         vmin=vmin_H, vmax=vmax_H)

axs[0, 1].set_title("B. Prey Amplitude ($c$ vs $E_P$)", fontsize=18)
axs[0, 1].set_xlabel("$E_P$", fontsize=16)
axs[0, 1].set_ylabel("$c$", fontsize=16)
axs[0, 1].tick_params(axis='both', labelsize=14)
axs[0, 1].text(0.025, 0.7, 'Predator\nOnly', transform=axs[0, 1].transAxes, fontsize=12, color='darkviolet')
axs[0, 1].text(0.3, 0.55, 'Coexistence', transform=axs[0, 1].transAxes, fontsize=12, color='royalblue')
axs[0, 1].text(0.7, 0.55, 'Prey Only', transform=axs[0, 1].transAxes, fontsize=12, color='darkgreen')

# Panel C: Predator amplitude for b
axs[1, 0].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS2 = axs[1, 0].contourf(E_P_array, b_array, amp_P_b_masked, 
                         levels=10, cmap='plasma', alpha=0.9, 
                         vmin=vmin_P, vmax=vmax_P)

axs[1, 0].set_title("C. Predator Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[1, 0].set_xlabel("$E_P$", fontsize=16)
axs[1, 0].set_ylabel("$b$", fontsize=16)
axs[1, 0].tick_params(axis='both', labelsize=14)
axs[1, 0].text(0.05, 0.7, 'Predator\nOnly', transform=axs[1, 0].transAxes, fontsize=12, color='darkviolet')
axs[1, 0].text(0.35, 0.55, 'Coexistence', transform=axs[1, 0].transAxes, fontsize=12, color='royalblue')
axs[1, 0].text(0.75, 0.4, 'Prey Only', transform=axs[1, 0].transAxes, fontsize=12, color='darkgreen')

# Panel D: Predator amplitude for c
axs[1, 1].imshow(region_data_c, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(c_array), max(c_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS3 = axs[1, 1].contourf(E_P_array, c_array, amp_P_c_masked, 
                         levels=10, cmap='plasma', alpha=0.9, 
                         vmin=vmin_P, vmax=vmax_P)

axs[1, 1].set_title("D. Predator Amplitude ($c$ vs $E_P$)", fontsize=18)
axs[1, 1].set_xlabel("$E_P$", fontsize=16)
axs[1, 1].set_ylabel("$c$", fontsize=16)
axs[1, 1].tick_params(axis='both', labelsize=14)
axs[1, 1].text(0.025, 0.7, 'Predator\nOnly', transform=axs[1, 1].transAxes, fontsize=12, color='darkviolet')
axs[1, 1].text(0.3, 0.55, 'Coexistence', transform=axs[1, 1].transAxes, fontsize=12, color='royalblue')
axs[1, 1].text(0.7, 0.55, 'Prey Only', transform=axs[1, 1].transAxes, fontsize=12, color='darkgreen')

# Colorbars
cbar_ax1 = fig.add_axes([0.93, 0.58, 0.015, 0.3])
cbar1 = fig.colorbar(CS1, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)
cbar1.ax.tick_params(labelsize=12)

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.015, 0.3])
cbar2 = fig.colorbar(CS2, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)
cbar2.ax.tick_params(labelsize=12)

plt.tight_layout(rect=[0, 0, 0.9, 1])

#plt.savefig("manuscript_figs/b_c_EP_regions_amplitude.jpg",
 #           format='jpeg',
  #          dpi=300,
   #         bbox_inches='tight')

plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:103: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# ## Trying subplots

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 7), sharex=True, sharey=True)

# Panel A: Prey amplitude ($b$ vs $E_P$)
axs[0].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS0 = axs[0].contourf(E_P_array, b_array, amp_H_b_masked, 
                      levels=10, cmap='viridis', alpha=0.9, 
                      vmin=vmin_H, vmax=vmax_H)

axs[0].set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[0].set_xlabel("$E_P$", fontsize=16)
axs[0].set_ylabel("$b$", fontsize=16)
axs[0].tick_params(axis='both', labelsize=14)
axs[0].text(0.05, 0.7, 'Predator\nOnly', transform=axs[0].transAxes, fontsize=12, color='darkviolet')
axs[0].text(0.35, 0.55, 'Coexistence', transform=axs[0].transAxes, fontsize=12, color='royalblue')
axs[0].text(0.75, 0.4, 'Prey Only', transform=axs[0].transAxes, fontsize=12, color='darkgreen')

# Panel B: Predator amplitude ($b$ vs $E_P$)
axs[1].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS1 = axs[1].contourf(E_P_array, b_array, amp_P_b_masked, 
                      levels=10, cmap='plasma', alpha=0.9, 
                      vmin=vmin_P, vmax=vmax_P)

axs[1].set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[1].set_xlabel("$E_P$", fontsize=16)
axs[1].tick_params(axis='both', labelsize=14)
axs[1].text(0.05, 0.7, 'Predator\nOnly', transform=axs[1].transAxes, fontsize=12, color='darkviolet')
axs[1].text(0.35, 0.55, 'Coexistence', transform=axs[1].transAxes, fontsize=12, color='royalblue')
axs[1].text(0.75, 0.4, 'Prey Only', transform=axs[1].transAxes, fontsize=12, color='darkgreen')

# Colorbars
cbar_ax1 = fig.add_axes([0.93, 0.58, 0.015, 0.3])
cbar1 = fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)
cbar1.ax.tick_params(labelsize=12)

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.015, 0.3])
cbar2 = fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)
cbar2.ax.tick_params(labelsize=12)

plt.tight_layout(rect=[0, 0, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:47: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
from matplotlib.patches import Patch

fig, axs = plt.subplots(1, 2, figsize=(16, 7), sharex=True, sharey=True)

# --- Panel A: Prey Amplitude ($b$ vs $E_P$) ---
axs[0].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS0 = axs[0].contourf(E_P_array, b_array, amp_H_b_masked, 
                      levels=10, cmap='viridis', alpha=0.9, 
                      vmin=vmin_H, vmax=vmax_H)

axs[0].set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[0].set_xlabel("$E_P$", fontsize=16)
axs[0].set_ylabel("$b$", fontsize=16)
axs[0].tick_params(axis='both', labelsize=14)
#axs[0].text(0.05, 0.7, 'Predator\nOnly', transform=axs[0].transAxes, fontsize=12, color='darkviolet')
#axs[0].text(0.35, 0.55, 'Coexistence', transform=axs[0].transAxes, fontsize=12, color='royalblue')
#axs[0].text(0.75, 0.4, 'Prey Only', transform=axs[0].transAxes, fontsize=12, color='darkgreen')

# --- Panel B: Predator Amplitude ($b$ vs $E_P$) ---
axs[1].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS1 = axs[1].contourf(E_P_array, b_array, amp_P_b_masked, 
                      levels=10, cmap='plasma', alpha=0.9, 
                      vmin=vmin_P, vmax=vmax_P)

axs[1].set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[1].set_xlabel("$E_P$", fontsize=16)
axs[1].tick_params(axis='both', labelsize=14)
#axs[1].text(0.05, 0.7, 'Predator\nOnly', transform=axs[1].transAxes, fontsize=12, color='darkviolet')
#axs[1].text(0.35, 0.55, 'Coexistence', transform=axs[1].transAxes, fontsize=12, color='royalblue')
#axs[1].text(0.75, 0.4, 'Prey Only', transform=axs[1].transAxes, fontsize=12, color='darkgreen')

# --- Colorbars ---
cbar_ax1 = fig.add_axes([0.93, 0.58, 0.015, 0.3])
cbar1 = fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)
cbar1.ax.tick_params(labelsize=12)

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.015, 0.3])
cbar2 = fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)
cbar2.ax.tick_params(labelsize=12)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]

fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])  # Adjust to leave space for legend
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

fig, axs = plt.subplots(1, 2, figsize=(16, 7), sharex=True, sharey=True)

# --- Panel A: Prey Amplitude ($b$ vs $E_P$) ---
axs[0].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS0 = axs[0].contourf(E_P_array, b_array, amp_H_b_masked, 
                      levels=10, cmap='viridis', alpha=0.9, 
                      vmin=vmin_H, vmax=vmax_H)

axs[0].set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[0].set_xlabel("$E_P$", fontsize=16)
axs[0].set_ylabel("$b$", fontsize=16)
axs[0].tick_params(axis='both', labelsize=14)

# --- Panel B: Predator Amplitude ($b$ vs $E_P$) ---
axs[1].imshow(region_data_b, cmap=cmap_regions,
              extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
              origin='lower', aspect='auto', alpha=0.5)

CS1 = axs[1].contourf(E_P_array, b_array, amp_P_b_masked, 
                      levels=10, cmap='plasma', alpha=0.9, 
                      vmin=vmin_P, vmax=vmax_P)

axs[1].set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=18)
axs[1].set_xlabel("$E_P$", fontsize=16)
axs[1].tick_params(axis='both', labelsize=14)

# --- Inset trajectory plots on predator amplitude plot ---
for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]

    # Simulate or run model
    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    # Create inset
    inset = inset_axes(axs[1], width=1.6, height=1.2, loc='center',
                       bbox_to_anchor=(ep_val +0.5, b_val -0.015),
                       bbox_transform=axs[1].transData, borderpad=0)

    inset.plot(time, H_array, color='limegreen', linewidth=0.8)
    inset.plot(time, P_array, color='purple', linewidth=0.8)

    # Clean up formatting
    inset.set_xticks([])
    inset.set_yticks([])
    inset.set_xlim(0, len(time))
    inset.set_ylim(0, max(np.max(H_array), np.max(P_array)) * 1.05)
    inset.set_facecolor("white")
    inset.patch.set_edgecolor('gray')
    inset.patch.set_linewidth(0.5)
    for spine in inset.spines.values():
        spine.set_color('gray')
        spine.set_linewidth(0.5)
        
        # Add a connection line
    con = ConnectionPatch(
        xyA=(0.5, 0.5), coordsA=inset.transAxes,
        xyB=(ep_val, b_val), coordsB=axs[1].transData,
        axesA=inset, axesB=axs[1],
        arrowstyle='-', color='gray', lw=1.0, zorder=3
    )
    fig.add_artist(con)

# --- Colorbars ---
cbar_ax1 = fig.add_axes([0.93, 0.58, 0.015, 0.3])
cbar1 = fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)
cbar1.ax.tick_params(labelsize=12)

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.015, 0.3])
cbar2 = fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)
cbar2.ax.tick_params(labelsize=12)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]

fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])  # Leave space for legend
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:94: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # Adding in trajectories

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch, ConnectionPatch
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(18, 14))
gs = gridspec.GridSpec(3, 2, height_ratios=[1.2, 1, 1])  # Top row for amplitudes, 2 bottom rows for trajectories

# --- Amplitude plots ---
ax_prey = fig.add_subplot(gs[0, 0])
ax_pred = fig.add_subplot(gs[0, 1])

# Prey amplitude
ax_prey.imshow(region_data_b, cmap=cmap_regions,
               extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
               origin='lower', aspect='auto', alpha=0.5)

CS0 = ax_prey.contourf(E_P_array, b_array, amp_H_b_masked, 
                       levels=10, cmap='viridis', alpha=0.9, 
                       vmin=vmin_H, vmax=vmax_H)

ax_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=18)
ax_prey.set_xlabel("$E_P$", fontsize=16)
ax_prey.set_ylabel("$b$", fontsize=16)

# Predator amplitude
ax_pred.imshow(region_data_b, cmap=cmap_regions,
               extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
               origin='lower', aspect='auto', alpha=0.5)

CS1 = ax_pred.contourf(E_P_array, b_array, amp_P_b_masked, 
                       levels=10, cmap='plasma', alpha=0.9, 
                       vmin=vmin_P, vmax=vmax_P)

ax_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=18)
ax_pred.set_xlabel("$E_P$", fontsize=16)

# --- Trajectories ---
trajectory_axes = []
for k in range(4):
    row = 1 + k // 2
    col = k % 2
    ax_traj = fig.add_subplot(gs[row, col])
    trajectory_axes.append(ax_traj)

# --- Populate trajectories and link them ---
for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})

    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax = trajectory_axes[k]
    ax.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax.set_title(
        f"{percentiles[k]}th %ile\nb={b_val:.2f}, Eₚ={ep_val:.2f}",
        fontsize=11
    )
    ax.text(
        0.95, 0.95,
        f"$N$ Amp = {amp_H:.1f}\n$P$ Amp = {amp_P:.1f}",
        transform=ax.transAxes,
        fontsize=10,
        ha='right',
        va='top',
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )
    ax.set_xlabel("Time")
    if k == 0:
        ax.set_ylabel("Biomass")
        ax.legend(fontsize=9)

    # --- Draw a line from this subplot to the predator amp plot location ---
    ep_plot_val = ep_val
    b_plot_val = b_val

    con = ConnectionPatch(
        xyA=(ep_plot_val, b_plot_val), coordsA=ax_pred.transData,
        xyB=(0.5, 1.0), coordsB=ax.transAxes,
        arrowstyle='->', color='black', linewidth=1.2
    )
    fig.add_artist(con)

# --- Colorbars ---
cbar_ax1 = fig.add_axes([0.93, 0.66, 0.015, 0.25])
cbar1 = fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)
cbar1.ax.tick_params(labelsize=12)

cbar_ax2 = fig.add_axes([0.93, 0.33, 0.015, 0.25])
cbar2 = fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)
cbar2.ax.tick_params(labelsize=12)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:111: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig = plt.figure(figsize=(20, 12))
gs = gridspec.GridSpec(2, 3, width_ratios=[1.5, 1, 1], height_ratios=[1, 1])

# --- Amplitude Panels (Left column) ---
ax_amp_prey = fig.add_subplot(gs[0, 0])
ax_amp_pred = fig.add_subplot(gs[1, 0])

# Prey Amplitude Plot
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions,
                   extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
                   origin='lower', aspect='auto', alpha=0.5)
CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

# Predator Amplitude Plot
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions,
                   extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
                   origin='lower', aspect='auto', alpha=0.5)
CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# --- Trajectory Axes (2x4: 4 for prey, 4 for predator) ---
traj_axes_prey = []
traj_axes_pred = []

for k in range(4):
    # Top row: Prey trajectories
    ax = fig.add_subplot(gs[0, 1 + k % 2])
    traj_axes_prey.append(ax)
    
    # Bottom row: Predator trajectories
    ax = fig.add_subplot(gs[1, 1 + k % 2])
    traj_axes_pred.append(ax)

# --- Plot trajectories + connect to amplitude locations ---
for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    # --- Prey Trajectory Plot ---
    ax_prey = traj_axes_prey[k]
    ax_prey.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_prey.set_title(f"{percentiles[k]}th %ile\nb={b_val:.2f}, Eₚ={ep_val:.2f}", fontsize=10)
    ax_prey.set_xlabel("Time")
    if k == 0:
        ax_prey.set_ylabel("Biomass")
        ax_prey.legend(fontsize=9)

    con_prey = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_prey.transData,
        xyB=(0.5, 1.0), coordsB=ax_prey.transAxes,
        arrowstyle='->', color='black', linewidth=1.2
    )
    fig.add_artist(con_prey)

    # --- Predator Trajectory Plot ---
    ax_pred = traj_axes_pred[k]
    ax_pred.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_pred.set_xlabel("Time")
    if k == 0:
        ax_pred.set_ylabel("Biomass")
        ax_pred.legend(fontsize=9)

    con_pred = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_pred.transData,
        xyB=(0.5, 1.0), coordsB=ax_pred.transAxes,
        arrowstyle='->', color='black', linewidth=1.2
    )
    fig.add_artist(con_pred)

# --- Colorbars ---
cbar_ax1 = fig.add_axes([0.93, 0.56, 0.015, 0.25])
cbar1 = fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks)
cbar1.set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.93, 0.12, 0.015, 0.25])
cbar2 = fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks)
cbar2.set_label("Predator Amplitude", fontsize=14)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:33: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:102: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig = plt.figure(figsize=(20, 12))
outer_gs = gridspec.GridSpec(2, 3, width_ratios=[1.5, 1, 1], height_ratios=[1, 1])

# --- Amplitude Panels (Left column) ---
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

# Plot amplitude panels
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions,
                   extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
                   origin='lower', aspect='auto', alpha=0.5)
CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

ax_amp_pred.imshow(region_data_b, cmap=cmap_regions,
                   extent=[min(E_P_array), max(E_P_array), min(b_array), max(b_array)],
                   origin='lower', aspect='auto', alpha=0.5)
CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# --- Create 2x2 trajectory grids for prey and predator ---
gs_traj_prey = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[0, 1:])
gs_traj_pred = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[1, 1:])

traj_axes_prey = [fig.add_subplot(gs_traj_prey[i, j]) for i in range(2) for j in range(2)]
traj_axes_pred = [fig.add_subplot(gs_traj_pred[i, j]) for i in range(2) for j in range(2)]

# --- Plot trajectories + connect to amplitude maps ---
for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    # --- Prey trajectory ---
    ax_prey = traj_axes_prey[k]
    ax_prey.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_prey.set_title(f"{percentiles[k]}th %ile\nb={b_val:.2f}, Eₚ={ep_val:.2f}", fontsize=10)
    ax_prey.set_xlabel("Time")
    if k in [0, 2]:
        ax_prey.set_ylabel("Biomass")
    if k == 0:
        ax_prey.legend(fontsize=9)

    con_prey = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_prey.transData,
        xyB=(0.5, 1.0), coordsB=ax_prey.transAxes,
        arrowstyle='->', color='black', linewidth=1.2
    )
    fig.add_artist(con_prey)

    # --- Predator trajectory ---
    ax_pred = traj_axes_pred[k]
    ax_pred.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_pred.set_xlabel("Time")
    if k in [0, 2]:
        ax_pred.set_ylabel("Biomass")
    if k == 0:
        ax_pred.legend(fontsize=9)

    con_pred = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_pred.transData,
        xyB=(0.5, 1.0), coordsB=ax_pred.transAxes,
        arrowstyle='->', color='black', linewidth=1.2
    )
    fig.add_artist(con_pred)

# --- Colorbars ---
cbar_ax1 = fig.add_axes([0.93, 0.56, 0.015, 0.25])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.93, 0.12, 0.015, 0.25])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator Amplitude", fontsize=14)

# --- Unified Legend ---
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:95: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# Create figure
fig = plt.figure(figsize=(20, 12))
outer_gs = GridSpec(2, 3, width_ratios=[1.5, 1, 1], height_ratios=[1, 1])

# Amplitude plots
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# Create 2x2 trajectory grids for prey and predator
gs_traj_prey = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[0, 1:])
gs_traj_pred = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[1, 1:])

traj_axes_prey = [fig.add_subplot(gs_traj_prey[i, j]) for i in range(2) for j in range(2)]
traj_axes_pred = [fig.add_subplot(gs_traj_pred[i, j]) for i in range(2) for j in range(2)]
#traj_axes_prey = [fig.add_subplot(gs_traj_prey[i]) for i in range(3)]
#traj_axes_pred = [fig.add_subplot(gs_traj_pred[i]) for i in range(3)]

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]
    label = f"{chr(65 + k)}"  # A, B, C, D

    # mark on amplitude plots
    #ax_amp_prey.scatter(ep_val, b_val, color='black', s=50, zorder=5)
    #ax_amp_prey.text(ep_val + 0.01, b_val + 0.005, f"P{label}", fontsize=10, color='black')
    ax_amp_prey.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
    ax_amp_prey.text(ep_val + 0.01, b_val + 0.005, f"P{label}", fontsize=12, fontweight='bold', color='white',
                 bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    #ax_amp_pred.scatter(ep_val, b_val, color='black', s=50, zorder=5)
    #ax_amp_pred.text(ep_val + 0.01, b_val + 0.005, f"D{label}", fontsize=10, color='black')
    ax_amp_pred.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
    ax_amp_pred.text(ep_val + 0.01, b_val + 0.005, f"P{label}", fontsize=12, fontweight='bold', color='white',
                 bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax_prey = traj_axes_prey[k]
    ax_prey.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_prey.plot(time, P_array, color='grey', label='Predator ($P$)')
    ax_prey.set_title(f"P{label}: {percentiles[k]}th %ile", fontsize=10)
    ax_prey.set_xlabel("Time")
    if k in [0, 2]:
        ax_prey.set_ylabel("Biomass")
    if k == 0:
        ax_prey.legend(fontsize=9)

    ax_pred = traj_axes_pred[k]
    ax_pred.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_pred.plot(time, H_array, color='grey', label='Prey ($N$)')
    ax_pred.set_title(f"D{label}: {percentiles[k]}th %ile", fontsize=10)
    ax_pred.set_xlabel("Time")
    if k in [0, 2]:
        ax_pred.set_ylabel("Biomass")
    if k == 0:
        ax_pred.legend(fontsize=9)

# Colorbars
cbar_ax1 = fig.add_axes([0.93, 0.56, 0.015, 0.25])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.93, 0.12, 0.015, 0.25])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator Amplitude", fontsize=14)

# Unified Legend
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:97: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # Predator trajectories

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_P_b_masked[~np.isnan(amp_P_b_masked)]
percentiles = [10, 50, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
np.random.seed(42)
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_P_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

fig, axs = plt.subplots(1, 3, figsize=(20, 4), sharex=True)

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))
    
    axs[k].plot(time, H_array, color='limegreen', label='Prey ($N$)')
    axs[k].plot(time, P_array, color='purple', label='Predator ($P$)')
    
    axs[k].set_title(
    f"{percentiles[k]}th Percentile Amplitude\nb = {b_val:.2f}, Eₚ = {ep_val:.2f}",
    fontsize=11
    )

    axs[k].text(
    0.95, 0.95,
    f"$N$ Amp. = {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
    transform=axs[k].transAxes,
    fontsize=10,
    ha='right',
    va='top',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    axs[k].tick_params(labelsize=10)
    if k == 0:
        axs[k].set_ylabel("Biomass")
        axs[k].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Prey Trajectories

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_H_b_masked[~np.isnan(amp_H_b_masked)]
percentiles = [10, 50, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
np.random.seed(42)
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_H_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

fig, axs = plt.subplots(1, 3, figsize=(20, 4), sharex=True)

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))
    
    axs[k].plot(time, H_array, color='limegreen', label='Prey ($N$)')
    axs[k].plot(time, P_array, color='purple', label='Predator ($P$)')
    
    axs[k].set_title(
    f"{percentiles[k]}th Percentile Amplitude\nb = {b_val:.2f}, Eₚ = {ep_val:.2f}",
    fontsize=11
    )

    axs[k].text(
    0.95, 0.95,
    f"$N$ Amp. = {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
    transform=axs[k].transAxes,
    fontsize=10,
    ha='right',
    va='top',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    axs[k].tick_params(labelsize=10)
    if k == 0:
        axs[k].set_ylabel("Biomass")
        axs[k].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Create figure
fig = plt.figure(figsize=(18, 12))
outer_gs = GridSpec(2, 2, width_ratios=[1.5, 1.0], height_ratios=[1, 1], wspace=0.3)

# Amplitude plots
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# Trajectory subplots
gs_traj_prey = GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[0, 1])
gs_traj_pred = GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[1, 1])
traj_axes_prey = [fig.add_subplot(gs_traj_prey[i]) for i in range(3)]
traj_axes_pred = [fig.add_subplot(gs_traj_pred[i]) for i in range(3)]

# --- Updated prey-selected indices based on prey amplitude percentiles ---
parameters_dict = default_params()
valid_amps_prey = amp_H_b_masked[~np.isnan(amp_H_b_masked)]
percentiles = [10, 50, 90]
amp_thresholds_prey = np.percentile(valid_amps_prey, percentiles)

#selected_indices_prey = []
#for val in amp_thresholds_prey:
 #   diff = np.abs(amp_H_b_masked - val)
  #  diff[~constrained_mask_cycles_b] = np.nan
   # idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    #selected_indices_prey.append(idx)

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    label = f"{chr(65 + k)}"

    for ax in [ax_amp_prey, ax_amp_pred]:
        ax.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
        ax.text(ep_val + 0.01, b_val + 0.005, f"{label}", fontsize=12, fontweight='bold', color='white',
                bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    #H_array, P_array, *_ = run_model(1, 1, {'b': b_val, 'c': 0.4, 'E_P': ep_val})
    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax_prey = traj_axes_prey[k]
    ax_prey.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_prey.plot(time, P_array, color='grey', label='Predator ($P$)')
    ax_prey.set_title(f"{label}: b = {b_val:.2f}, Eₚ = {ep_val:.2f}", fontsize=10)
    if k == 0:
        ax_prey.set_ylabel("Biomass")
        ax_prey.legend(fontsize=9)
    ax_prey.set_xlabel("Time")

    ax_pred = traj_axes_pred[k]
    ax_pred.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_pred.plot(time, H_array, color='grey', label='Prey ($N$)')
    ax_pred.set_title(f"{label}: b = {b_val:.2f}, Eₚ = {ep_val:.2f}", fontsize=10)
    if k == 0:
        ax_pred.set_ylabel("Biomass")
        ax_pred.legend(fontsize=9)
    ax_pred.set_xlabel("Time")

# Colorbars
cbar_ax1 = fig.add_axes([0.93, 0.58, 0.015, 0.3])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.93, 0.12, 0.015, 0.3])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator Amplitude", fontsize=14)

# Unified Legend
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:96: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
from matplotlib.patches import FancyArrowPatch

# %%
# --- Prey-selected indices based on prey amplitude percentiles ---
parameters_dict = default_params()
valid_amps_prey = amp_H_b_masked[~np.isnan(amp_H_b_masked)]
percentiles = [10, 50, 90]
amp_thresholds_prey = np.percentile(valid_amps_prey, percentiles)

selected_indices_prey = []
for val in amp_thresholds_prey:
    diff = np.abs(amp_H_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices_prey.append(idx)

# --- Predator-selected indices based on predator amplitude percentiles ---
valid_amps_pred = amp_P_b_masked[~np.isnan(amp_P_b_masked)]
amp_thresholds_pred = np.percentile(valid_amps_pred, percentiles)

selected_indices_pred = []
for val in amp_thresholds_pred:
    diff = np.abs(amp_P_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices_pred.append(idx)

# Create figure
fig = plt.figure(figsize=(18, 12))
outer_gs = GridSpec(2, 2, width_ratios=[1.5, 1.0], height_ratios=[1, 1], wspace=0.15)

# Amplitude plots
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# Trajectory subplots
gs_traj_prey = GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[0, 1], hspace=0.4)
gs_traj_pred = GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[1, 1], hspace=0.4)
traj_axes_prey = [fig.add_subplot(gs_traj_prey[i]) for i in range(3)]
traj_axes_pred = [fig.add_subplot(gs_traj_pred[i]) for i in range(3)]

# Set consistent x-limits across all trajectory plots
for ax_group in [traj_axes_prey, traj_axes_pred]:
    for ax in ax_group:
        ax.set_xlim([0, time[-1]])
        ax.label_outer()  # Hides x-axis labels except bottom one

# Only show x-axis label on bottom subplot of each group
traj_axes_prey[-1].set_xlabel("Time")
traj_axes_pred[-1].set_xlabel("Time")

# Prey Trajectories

offsets_prey = [(-0.06, 0.017), (-0.06, 0.02), (-0.06, 0.02)]  # (dx, dy) for labels A, B, C

for k, (i, j) in enumerate(selected_indices_prey):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    label = f"{chr(65 + k)}"
    
    dx, dy = offsets_prey[k]  # unique offset for each point

    ax_amp_prey.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
    ax_amp_prey.text(ep_val + dx, b_val + dy, label, fontsize=12, fontweight='bold', color='white',
                     bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    #ax_amp_prey.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
    #ax_amp_prey.text(ep_val + 0.05, b_val + 0.05, label, fontsize=12, fontweight='bold', color='white',
                     #bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax = traj_axes_prey[k]
    ax.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax.plot(time, P_array, color='grey', label='Predator ($P$)')
    ax.set_title(f"{label}: $b$ = {b_val:.2f}, $Eₚ$ = {ep_val:.2f}", fontsize=10)
    if k == 0:
        ax.set_ylabel("Abundance")
        ax.legend(fontsize=9)
    ax.set_xlabel("Time (Years)")
    
    # Coordinates: (x, y) in data coords of amp plot -> axes coords of subplot
    con_prey = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_prey.transData,
        xyB=(0.05, 0.95), coordsB=traj_axes_prey[k].transAxes,
        axesA=ax_amp_prey, axesB=traj_axes_prey[k],
        color='grey', lw=1.0, linestyle='--'
    )
    fig.add_artist(con_prey)
    

# Predator Trajectories

offsets_pred = [(-0.06, 0.017), (-0.04, -0.06), (-0.05, 0.03)]  # (dx, dy) for labels A, B, C

for k, (i, j) in enumerate(selected_indices_pred):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    label = f"{chr(65 + k)}"
    
    dx, dy = offsets_pred[k]  # unique offset for each point

    ax_amp_pred.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
    ax_amp_pred.text(ep_val + dx, b_val + dy, label, fontsize=12, fontweight='bold', color='white',
                     bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=1.0))

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax = traj_axes_pred[k]
    ax.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax.plot(time, H_array, color='grey', label='Prey ($N$)')
    ax.set_title(f"{label}: $b$ = {b_val:.2f}, $Eₚ$ = {ep_val:.2f}", fontsize=10)
    if k == 0:
        ax.set_ylabel("Abundance")
        ax.legend(fontsize=9)
    ax.set_xlabel("Time (Years)")
    
    # --- Connecting lines from amplitude plot to predator trajectory ---
    con_pred = ConnectionPatch(
        xyA=(ep_val, b_val), coordsA=ax_amp_pred.transData,
        xyB=(0.05, 0.95), coordsB=traj_axes_pred[k].transAxes,
        axesA=ax_amp_pred, axesB=traj_axes_pred[k],
        color='grey', lw=1.0, linestyle='--'
    )

    fig.add_artist(con_pred)

# Colorbars
cbar_ax1 = fig.add_axes([0.15, 0.55, 0.005, 0.05])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey\nAmplitude", fontsize=10)

cbar_ax2 = fig.add_axes([0.23, 0.14, 0.005, 0.05])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator\nAmplitude", fontsize=10)

# Unified Legend
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
]
#fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=12, frameon=True)

ax_amp_pred.legend(handles=legend_elements,
                   loc='lower left',
                   fontsize=11,
                   frameon=True,
                   borderpad=0.8)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])



plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:169: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
from matplotlib.gridspec import GridSpecFromSubplotSpec

# Create 2-column layout: amplitudes on left, trajectories on right
fig = plt.figure(figsize=(16, 10))
outer_gs = GridSpec(2, 2, width_ratios=[1.3, 1.0], height_ratios=[1, 1], wspace=0.3)

# Amplitude plots (left column)
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

# Trajectory subplots (right column)
gs_traj = GridSpecFromSubplotSpec(3, 1, subplot_spec=outer_gs[:, 1])
traj_axes = [fig.add_subplot(gs_traj[i]) for i in range(3)]

# Plot amplitude panels
CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# Only plot 3 trajectories
for k, (i, j) in enumerate(selected_indices[:3]):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    label = f"{chr(65 + k)}"  # A, B, C

    # Mark locations on both amplitude plots
    for ax in [ax_amp_prey, ax_amp_pred]:
        ax.scatter(ep_val, b_val, color='black', edgecolor='white', s=120, zorder=5)
        ax.text(ep_val + 0.01, b_val + 0.005, f"{label}", fontsize=12, fontweight='bold', color='white',
                bbox=dict(facecolor='black', edgecolor='none', pad=1.5, alpha=0.8))

    # Simulate model
    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax_traj = traj_axes[k]
    ax_traj.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_traj.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_traj.set_title(f"{label}: b = {b_val:.2f}, Eₚ = {ep_val:.2f}", fontsize=11)
    ax_traj.set_xlabel("Time")
    if k == 0:
        ax_traj.set_ylabel("Biomass")
        ax_traj.legend(fontsize=9)

# Colorbars
cbar_ax1 = fig.add_axes([0.92, 0.58, 0.015, 0.3])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.92, 0.15, 0.015, 0.3])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator Amplitude", fontsize=14)

# Unified Legend
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:77: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# Create figure
fig = plt.figure(figsize=(20, 12))
outer_gs = GridSpec(2, 3, width_ratios=[1.5, 1, 1], height_ratios=[1, 1])

# Amplitude plots
ax_amp_prey = fig.add_subplot(outer_gs[0, 0])
ax_amp_pred = fig.add_subplot(outer_gs[1, 0])

CS0 = ax_amp_prey.contourf(E_P_array, b_array, amp_H_b_masked,
                           levels=10, cmap='viridis', alpha=0.9, vmin=vmin_H, vmax=vmax_H)
ax_amp_prey.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_prey.set_title("A. Prey Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_prey.set_ylabel("$b$", fontsize=14)

CS1 = ax_amp_pred.contourf(E_P_array, b_array, amp_P_b_masked,
                           levels=10, cmap='plasma', alpha=0.9, vmin=vmin_P, vmax=vmax_P)
ax_amp_pred.imshow(region_data_b, cmap=cmap_regions, alpha=0.5,
                   extent=[E_P_array.min(), E_P_array.max(), b_array.min(), b_array.max()],
                   origin='lower', aspect='auto')
ax_amp_pred.set_title("B. Predator Amplitude ($b$ vs $E_P$)", fontsize=16)
ax_amp_pred.set_xlabel("$E_P$", fontsize=14)
ax_amp_pred.set_ylabel("$b$", fontsize=14)

# Create 2x2 trajectory grids for prey and predator
gs_traj_prey = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[0, 1:])
gs_traj_pred = gridspec.GridSpecFromSubplotSpec(2, 2, subplot_spec=outer_gs[1, 1:])

traj_axes_prey = [fig.add_subplot(gs_traj_prey[i, j]) for i in range(2) for j in range(2)]
traj_axes_pred = [fig.add_subplot(gs_traj_pred[i, j]) for i in range(2) for j in range(2)]

colors = ['#E69F00', '#56B4E9', '#009E73', '#D55E00']

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]
    label = f"{chr(65 + k)}"  # A, B, C, D
    color = colors[k]

    # mark on amplitude plots
    #ax_amp_prey.scatter(ep_val, b_val, color='black', s=50, zorder=5)
    #ax_amp_prey.text(ep_val + 0.01, b_val + 0.005, f"P{label}", fontsize=10, color='black')
    # Amplitude plot markers with color
    ax_amp_prey.scatter(ep_val, b_val, color=color, edgecolor='white', s=120, zorder=5)
    ax_amp_prey.text(ep_val + 0.01, b_val + 0.005, f"P{label}", fontsize=12, fontweight='bold', color='white',
                 bbox=dict(facecolor=color, edgecolor='none', pad=1.5, alpha=0.9))

    #ax_amp_pred.scatter(ep_val, b_val, color='black', s=50, zorder=5)
    #ax_amp_pred.text(ep_val + 0.01, b_val + 0.005, f"D{label}", fontsize=10, color='black')
    ax_amp_pred.scatter(ep_val, b_val, color=color, edgecolor='white', s=120, zorder=5)
    ax_amp_pred.text(ep_val + 0.01, b_val + 0.005, f"D{label}", fontsize=12, fontweight='bold', color='white',
                 bbox=dict(facecolor=color, edgecolor='none', pad=1.5, alpha=0.9))

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    ax_prey = traj_axes_prey[k]
    for spine in ax_prey.spines.values():
        spine.set_edgecolor(color)
        spine.set_linewidth(2)
    ax_prey.plot(time, H_array, color='limegreen', label='Prey ($N$)')
    ax_prey.plot(time, P_array, color='grey', label='Predator ($P$)')
    ax_prey.set_title(f"P{label}: {percentiles[k]}th %ile", fontsize=10)
    ax_prey.set_xlabel("Time")
    if k in [0, 2]:
        ax_prey.set_ylabel("Biomass")
    if k == 0:
        ax_prey.legend(fontsize=9)

    ax_pred = traj_axes_pred[k]
    for spine in ax_pred.spines.values():
        spine.set_edgecolor(color)
        spine.set_linewidth(2)
    ax_pred.plot(time, P_array, color='purple', label='Predator ($P$)')
    ax_pred.plot(time, H_array, color='grey', label='Prey ($N$)')
    ax_pred.set_title(f"D{label}: {percentiles[k]}th %ile", fontsize=10)
    ax_pred.set_xlabel("Time")
    if k in [0, 2]:
        ax_pred.set_ylabel("Biomass")
    if k == 0:
        ax_pred.legend(fontsize=9)

# Colorbars
cbar_ax1 = fig.add_axes([0.93, 0.56, 0.015, 0.25])
fig.colorbar(CS0, cax=cbar_ax1, ticks=prey_ticks).set_label("Prey Amplitude", fontsize=14)

cbar_ax2 = fig.add_axes([0.93, 0.12, 0.015, 0.25])
fig.colorbar(CS1, cax=cbar_ax2, ticks=pred_ticks).set_label("Predator Amplitude", fontsize=14)

# Unified Legend
legend_elements = [
    Patch(color='lightblue', label='Coexistence'),
    Patch(color='green', label='Prey Only'),
    Patch(color='purple', label='Predator Only'),
    Patch(facecolor='white', edgecolor='black', hatch='////', label='Prey Cycles'),
    Patch(facecolor='white', edgecolor='black', hatch='\\\\', label='Predator Cycles')
]

fig.legend(handles=legend_elements, loc='lower center', ncol=5, fontsize=14, frameon=True)

plt.tight_layout(rect=[0, 0.05, 0.9, 1])
plt.show()
# Out:
# /Users/SophiaRahnke/opt/miniconda3/envs/py36test/lib/python3.6/site-packages/ipykernel_launcher.py:106: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# ## Selected Amplitude Time Series

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_P_b_masked[~np.isnan(amp_P_b_masked)]
percentiles = [10, 40, 70, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_P_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

# Simulate time series for each (b, E_P) pair
fig, axs = plt.subplots(2, 4, figsize=(18, 6), sharex=True)
#time = np.arange(400)  # assuming 400 years

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))  # <-- dynamically match the model output
    
    axs[0, k].plot(time, H_array, color='green')
    axs[0, k].set_title(f"b = {b_val:.2f}, E_P = {ep_val:.2f}", fontsize=11)
    axs[1, k].plot(time, P_array, color='darkred')
    
    if k == 0:
        axs[0, k].set_ylabel("Prey (H)")
        axs[1, k].set_ylabel("Predator (P)")

for ax in axs[1]:
    ax.set_xlabel("Time")

plt.tight_layout()
plt.show()

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_P_b_masked[~np.isnan(amp_P_b_masked)]
percentiles = [10, 40, 70, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_P_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

# Simulate time series for each (b, E_P) pair
fig, axs = plt.subplots(2, 4, figsize=(18, 6), sharex=True)
#time = np.arange(400)  # assuming 400 years

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_val = amp_P_b_masked[i, j]  # Get amplitude for labeling

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))
    
    axs[0, k].plot(time, H_array, color='green')
    axs[0, k].set_title(f"b = {b_val:.2f}, E_P = {ep_val:.2f}\nAmp = {amp_val:.1f}", fontsize=11)
    axs[1, k].plot(time, P_array, color='darkred')
    
    if k == 0:
        axs[0, k].set_ylabel("Prey (H)")
        axs[1, k].set_ylabel("Predator (P)")

for ax in axs[1]:
    ax.set_xlabel("Time")

plt.tight_layout()
plt.show()

# %% [markdown]
# # $b$ and $E_P$ amplitudes

# %% [markdown]
# # $b$ and pred amp

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_P_b_masked[~np.isnan(amp_P_b_masked)]
percentiles = [10, 50, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_P_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

fig, axs = plt.subplots(1, 4, figsize=(20, 4), sharex=True)

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))
    
    axs[k].plot(time, H_array, color='limegreen', label='Prey ($N$)')
    axs[k].plot(time, P_array, color='purple', label='Predator ($P$)')
    
    axs[k].set_title(
    f"{percentiles[k]}th Percentile Amplitude\nb = {b_val:.2f}, Eₚ = {ep_val:.2f}",
    fontsize=11
    )

    axs[k].text(
    0.95, 0.95,
    f"$N$ Amp. = {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
    transform=axs[k].transAxes,
    fontsize=10,
    ha='right',
    va='top',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    axs[k].tick_params(labelsize=10)
    if k == 0:
        axs[k].set_ylabel("Biomass")
        axs[k].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()

# %%
parameters_dict = default_params()
# Select 4 predator amplitude percentiles from b vs E_P space
valid_amps = amp_H_b_masked[~np.isnan(amp_H_b_masked)]
percentiles = [10, 40, 70, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_H_b_masked - val)
    diff[~constrained_mask_cycles_b] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

fig, axs = plt.subplots(1, 4, figsize=(20, 4), sharex=True)

for k, (i, j) in enumerate(selected_indices):
    b_val = b_array[i]
    ep_val = E_P_array[j]
    amp_H = amp_H_b_masked[i, j]
    amp_P = amp_P_b_masked[i, j]

    params = parameters_dict.copy()
    params.update({'b': b_val, 'c': 0.4, 'E_P': ep_val})
    
    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))
    
    axs[k].plot(time, H_array, color='limegreen', label='Prey ($N$)')
    axs[k].plot(time, P_array, color='purple', label='Predator ($P$)')
    
    axs[k].set_title(
    f"{percentiles[k]}th Percentile Amplitude\nb = {b_val:.2f}, Eₚ = {ep_val:.2f}",
    fontsize=11
    )

    axs[k].text(
    0.95, 0.95,
    f"$N$ Amp. = {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
    transform=axs[k].transAxes,
    fontsize=10,
    ha='right',
    va='top',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    axs[k].tick_params(labelsize=10)
    if k == 0:
        axs[k].set_ylabel("Biomass")
        axs[k].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # $C$ and $E_P$ Amplitudes

# %% [markdown]
# # $c$ and pred amp

# %%
parameters_dict = default_params()

# Select 4 predator amplitude percentiles from c vs E_P space
valid_amps = amp_P_c_masked[~np.isnan(amp_P_c_masked)]
percentiles = [10, 40, 70, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_P_c_masked - val)
    diff[~constrained_mask_cycles_c] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

# Plotting time series
fig, axs = plt.subplots(1, 4, figsize=(18, 4), sharex=True)
for k, (i, j) in enumerate(selected_indices):
    c_val = c_array[i]
    ep_val = E_P_array[j]
    amp_P = amp_P_c_masked[i, j]
    amp_H = amp_H_c_masked[i, j]

    params = parameters_dict.copy()
    params.update({'c': c_val, 'b': 0.4, 'E_P': ep_val})  # b fixed, c varies

    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    axs[k].plot(time, H_array, color='limegreen', label='Prey (N)')
    axs[k].plot(time, P_array, color='purple', label='Predator (P)')

    axs[k].set_title(
        f"{percentiles[k]}th Percentile Amplitude\nc = {c_val:.2f}, Eₚ = {ep_val:.2f}",
        fontsize=11
    )

    axs[k].text(
        0.95, 0.95,
        f"$N$ Amp.= {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
        transform=axs[k].transAxes,
        fontsize=10,
        ha='right',
        va='top',
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    if k == 0:
        axs[k].set_ylabel("Biomass")

# Optional: unified legend
axs[0].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # $c$ and prey amp

# %%
parameters_dict = default_params()

# Select 4 predator amplitude percentiles from c vs E_P space
valid_amps = amp_H_c_masked[~np.isnan(amp_H_c_masked)]
percentiles = [10, 40, 70, 90]
amp_thresholds = np.percentile(valid_amps, percentiles)

# Identify (i, j) closest to each percentile
selected_indices = []
for val in amp_thresholds:
    diff = np.abs(amp_H_c_masked - val)
    diff[~constrained_mask_cycles_c] = np.nan
    idx = np.unravel_index(np.nanargmin(diff), diff.shape)
    selected_indices.append(idx)

# Plotting time series
fig, axs = plt.subplots(1, 4, figsize=(18, 4), sharex=True)
for k, (i, j) in enumerate(selected_indices):
    c_val = c_array[i]
    ep_val = E_P_array[j]
    amp_P = amp_P_c_masked[i, j]
    amp_H = amp_H_c_masked[i, j]

    params = parameters_dict.copy()
    params.update({'c': c_val, 'b': 0.4, 'E_P': ep_val})  # b fixed, c varies

    H_array, P_array, *_ = run_model(H0, P0, params)
    time = np.arange(len(H_array))

    axs[k].plot(time, H_array, color='limegreen', label='Prey (N)')
    axs[k].plot(time, P_array, color='purple', label='Predator (P)')

    axs[k].set_title(
        f"{percentiles[k]}th Percentile Amplitude\nc = {c_val:.2f}, Eₚ = {ep_val:.2f}",
        fontsize=11
    )

    axs[k].text(
        0.95, 0.95,
        f"$N$ Amp.= {amp_H:.1f}\n$P$ Amp. = {amp_P:.1f}",
        transform=axs[k].transAxes,
        fontsize=10,
        ha='right',
        va='top',
        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
    )

    axs[k].set_xlabel("Time")
    if k == 0:
        axs[k].set_ylabel("Biomass")

# Optional: unified legend
axs[0].legend(loc='center right', fontsize=9)

plt.tight_layout()
plt.show()
